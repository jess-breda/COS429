# %%
import sys
sys.path += ['layers']
import numpy as np
from data_utils import get_CIFAR10_data

from init_base_model import init_base_model
from train_custom import train_custom

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load Data & Partition

# %%
X_train, y_train, X_test, y_test = get_CIFAR10_data()

### TRAIN DATA TINY
n_train = 100
X_train_tiny = X_train[:,:,:, :n_train]
y_train_tiny = y_train[:n_train]

### TEST/VALIDATION DATA TINY
n_test = 1000
X_test_tiny = X_test[:,:,:,:n_test]
y_test_tiny = y_test[:n_test]
# Out:
# Train data shape:  (32, 32, 3, 50000)
# Train labels shape:  (50000,)
# Test data shape:  (32, 32, 3, 10000)
# Test labels shape:  (10000,)

# %%
# SET PARAMS HERE
learning_rate = 1e-2 # already did 1e3, 1e4
weight_decay = 1e-5 # lready did 1e-6
batch_size = 64 # already did 32
live_plot_on = True
itr_to_plot = 10
verbose = True
early_stopping_on = True
calculate_test = True
itr_to_test = 25
numIters = 25 # already did 10k
save_file = f"\\test_dropout_model"
p_act = 1

# other params
# save_plot - if you want to save performance plot out (True)
# save path - where to put train model and plot (\results foler)

# PACK INTO PARAMS DICT
params = {
    "learning_rate" :learning_rate, # default 0.01
    "weight_decay":weight_decay ,   # default 0.0005
    "batch_size" : batch_size,      # default 128
    "save_file" : save_file,        # default model
    "live_plot_on" : live_plot_on,
    "itr_to_plot" : itr_to_plot,    # how many iterations until live plot refresh
    "verbose" : verbose,
    "early_stopping_on" : early_stopping_on, # defualt True
    "calculate_test": calculate_test,        # bool for validation checks, default true
    "itr_to_test": itr_to_test,              # n iterations between validation check
    "X_test" : X_test_tiny,                  # validation set, can be empty
    "y_test" : y_test_tiny,                  # validation set, can be empty
    "p_act" : p_act                       # for dropout percentage to keep active 
    }

# %%
model = init_base_model()
# Out:
# Input size:
# [32, 32, 3]
# Layer 0 output size:
# (28, 28, 3)
# Layer 1 output size:
# (14, 14, 3)
# Layer 2 output size:
# (14, 14, 3)
# Layer 3 output size:
# (588,)
# Layer 4 output size:
# (10,)
# Final output size:
# (10,)
# Provided output size (should match above):
# 10
# (Batch dimension not included)

# %%
trained_model, loss, accuracy, test_accuracy, time = train_custom(
    model,
    X_train_tiny, 
    y_train_tiny, 
    params, 
    numIters
    )
# Out:
# Fished itr 21 / 25; cost: 2.31486 train: 0.140625 val: 0.112
# Fished itr 22 / 25; cost: 2.23156 train: 0.25 val: 0.112
# Fished itr 23 / 25; cost: 2.19823 train: 0.25 val: 0.112
# Fished itr 24 / 25; cost: 2.18895 train: 0.15625 val: 0.112
# Time to train: 18.17

# %%
trained_model, loss, accuracy, test_accuracy, time = train_custom(
    model,
    X_train_tiny, 
    y_train_tiny, 
    params, 
    numIters
    )
# Out:
# Fished itr 21 / 25; cost: 7.84295 train: 0.078125 val: 0.085
# Fished itr 22 / 25; cost: 8.16835 train: 0.0625 val: 0.085
# Fished itr 23 / 25; cost: 7.80863 train: 0.15625 val: 0.085
# Fished itr 24 / 25; cost: 7.80814 train: 0.203125 val: 0.085
# Time to train: 18.43

# %%
trained_model, loss, accuracy, test_accuracy, time = train_custom(
    model,
    X_train_tiny, 
    y_train_tiny, 
    params, 
    numIters
    )
# Out:
# Fished itr 21 / 25; cost: 2.41393 train: 0.125 val: 0.118
# Fished itr 22 / 25; cost: 2.21098 train: 0.203125 val: 0.118
# Fished itr 23 / 25; cost: 2.18133 train: 0.203125 val: 0.118
# Fished itr 24 / 25; cost: 2.3765 train: 0.078125 val: 0.118
# Time to train: 18.15

# %%
np.linspace(.5,1, 5)
# Out:
# array([0.5  , 0.625, 0.75 , 0.875, 1.   ])
